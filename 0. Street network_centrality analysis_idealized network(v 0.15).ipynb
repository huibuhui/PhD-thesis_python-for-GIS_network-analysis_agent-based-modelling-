# %%
import networkx as nx
import numpy as np
import numpy as np
import geopandas as gpd
# import xlsxwriter
import networkx as nx
# import openpyxl

import pandas as pd
from pandas import DataFrame

import osmnx as ox
ox.config(log_file=True, log_console=True, use_cache=True)
ox.__version__

import shapely
from shapely.geometry import LineString
from shapely.geometry import Point


import matplotlib.cm as cm
import matplotlib.colors as colors

# %matplotlib inline
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
from matplotlib import pyplot as plt
from pylab import rcParams

# %matplotlib inline
import pandana, matplotlib.pyplot as plt
from pandana.loaders import osm

# %% [markdown]
# # Idealized / Decentralize Network

# %%
N = 13
G = nx. grid_2d_graph(N,N)
pos = dict ((n,n) for n in G.nodes())
# pos = nx.spring_layout(G, iterations = 100)
# labels = dict( ((i,j), i*10+j) for i, j in G.nodes())

#####Save output to csv file

# df = pd.DataFrame(dict(
#     bc = nx.betweenness_centrality(G),
# ))

# df.to_csv('E:/Thesis/Placement Effect/bc/bc_78.csv')


####Plot
cc = nx.closeness_centrality(G, u=None, distance=None, wf_improved=True)
bc = nx.betweenness_centrality(G, k=None, normalized=True, weight=None, endpoints=False, seed=None)
nc2 = [bc.get(node, 0.25) for node in G.nodes()] 
nx.draw(G, pos = pos,  font_color='black', node_color= nc2)

plt.axis('off')
plt.show()
